# %%
# This is a comment. It explains what the code does but isn't executed by Python.
# We are creating a variable to hold a welcome message string.
welcome_message = "Welcome to my AI & ML Internship Project!"

# The print() function displays whatever is passed inside the parentheses onto the screen.
print(welcome_message)

project_name = "Student Score Prediction"
print(project_name)
# Out:
# Welcome to my AI & ML Internship Project!
# Student Score Prediction
